# %% [markdown]
# # YOLO en Tiempo Real: Detección de Objetos
# ### Percepción Computacional - Universidad de los Hemisferios
# #### Maestría en Inteligencia Artificial Aplicada
#
# Bienvenidos a este cuaderno de Jupyter, donde exploraremos la emocionante tarea de la detección de objetos en tiempo real utilizando YOLO (You Only Look Once), una técnica avanzada de visión por computadora. Esta experiencia de aprendizaje forma parte del programa de la Maestría en Inteligencia Artificial Aplicada, impartido por la Universidad de los Hemisferios.
#
# En este cuaderno, aprenderás a utilizar YOLO para identificar y localizar diversos objetos en imágenes y secuencias de video. Esta habilidad es esencial en una amplia gama de aplicaciones, desde la conducción autónoma hasta la vigilancia de seguridad, y representa uno de los avances más emocionantes en el campo de la inteligencia artificial y la visión por computadora.
#
# A lo largo de este curso, explorarás conceptos clave como:
#
# - Detección de objetos en tiempo real.
# - Configuración de modelos YOLO pre-entrenados.
# - Interpretación de resultados de detección.
# - Aplicaciones prácticas de la detección de objetos.
#
# ¡Prepárate para sumergirte en un emocionante mundo de visión por computadora y adquirir habilidades valiosas que te servirán en tu carrera en inteligencia artificial y más allá!
#
# Recuerda consultar este cuaderno para acceder a los recursos y ejemplos que te ayudarán a comprender YOLO y la percepción computacional en tiempo real.
#
# Eugenio.

# %%
# Importamos las bibliotecas necesarias
pip install opencv-python
pip install ultralytics
from ultralytics import YOLO
import cv2
import math
# Out:
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in ./.venv/lib/python3.11/site-packages (from opencv-python) (1.26.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cargamos el modelo YOLO pre-entrenado
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
# Definimos una lista de nombres de clases para identificar objetos detectados
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ] # Aquí se enumeran todas las clases

# %%
# Configuramos la captura de video desde la cámara
cap = cv2.VideoCapture(0) # Se abre la cámara por defecto
cap.set(3, 640) # Ancho de la imagen
cap.set(4, 480) # Alto de la imagen

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = cap.read() # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

   # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos las coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Convertimos a valores enteros

            # Dibujamos la caja delimitadora en la imagen
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Obtenemos la confianza de la detección
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Mostramos el nombre de la clase junto a la caja delimitadora
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0) # Color: Azul
            thickness = 1
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Mostramos la imagen con las detecciones
    cv2.imshow('Webcam', img)

    # Salimos del bucle si se presiona la tecla 'q'
    if cv2.waitKey(1) == ord('q'):
        break

# Liberamos la cámara y cerramos todas las ventanas
cap.release()
cv2.destroyAllWindows()
# Out:
# 2023-10-23 23:04:45.726 Python[5795:7281621] =>> Checked Property: [cfen] 1667655022
# 2023-10-23 23:04:45.726 Python[5795:7281621] =>> Checked Property: [peen] 1885693294
# 2023-10-23 23:04:45.726 Python[5795:7281621] =>> Checked Property: [slen] 1936483694
# 2023-10-23 23:04:45.726 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.726 Python[5795:7281621] =>> Checked Property: [fden] 1717855598
# 2023-10-23 23:04:45.726 Python[5795:7281621] =>> Checked Property: [hbde] 1751278693
# 2023-10-23 23:04:45.726 Python[5795:7281621] =>> Checked Property: [flsh] 1718383464
# 2023-10-23 23:04:45.727 Python[5795:7281621] =>> Checked Property: [ascc] 1634952035
# 2023-10-23 23:04:45.727 Python[5795:7281621] =>> Checked Property: [cfen] 1667655022
# 2023-10-23 23:04:45.727 Python[5795:7281621] =>> Checked Property: [peen] 1885693294
# 2023-10-23 23:04:45.727 Python[5795:7281621] =>> Checked Property: [slen] 1936483694
# 2023-10-23 23:04:45.727 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.728 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.728 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.728 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.728 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.728 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.728 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.729 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.729 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.729 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.729 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.730 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.730 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.730 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.730 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.731 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.731 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.731 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.732 Python[5795:7281621] =>> Checked Property: [cfen] 1667655022
# 2023-10-23 23:04:45.732 Python[5795:7281621] =>> Checked Property: [peen] 1885693294
# 2023-10-23 23:04:45.732 Python[5795:7281621] =>> Checked Property: [slen] 1936483694
# 2023-10-23 23:04:45.733 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
# 2023-10-23 23:04:45.733 Python[5795:7281621] =>> Checked Property: [cfac] 1667653987
# 2023-10-23 23:04:45.733 Python[5795:7281621] =>> Checked Property: [slac] 1936482659
# 2023-10-23 23:04:45.734 Python[5795:7281621] =>> Checked Property: [strz] 1937011322
#
# 0: 480x640 (no detections), 287.5ms
# Speed: 6.8ms preprocess, 287.5ms inference, 11.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 266.7ms
# Speed: 6.1ms preprocess, 266.7ms inference, 10.4ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 185.3ms
# Speed: 2.1ms preprocess, 185.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 190.9ms
# Speed: 1.6ms preprocess, 190.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 179.4ms
# Speed: 1.5ms preprocess, 179.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 181.9ms
# Speed: 2.2ms preprocess, 181.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 181.3ms
# Speed: 1.9ms preprocess, 181.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 179.7ms
# Speed: 2.0ms preprocess, 179.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.7
# Class name --> person
# 0: 480x640 1 person, 178.0ms
# Speed: 1.9ms preprocess, 178.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 226.9ms
# Speed: 1.9ms preprocess, 226.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 178.7ms
# Speed: 2.2ms preprocess, 178.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 176.9ms
# Speed: 2.3ms preprocess, 176.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 177.2ms
# Speed: 2.1ms preprocess, 177.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 177.6ms
# Speed: 1.9ms preprocess, 177.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 176.8ms
# Speed: 2.0ms preprocess, 176.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 177.2ms
# Speed: 1.9ms preprocess, 177.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 178.0ms
# Speed: 1.9ms preprocess, 178.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 176.6ms
# Speed: 1.9ms preprocess, 176.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 176.9ms
# Speed: 2.0ms preprocess, 176.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 177.0ms
# Speed: 1.9ms preprocess, 177.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 179.2ms
# Speed: 1.9ms preprocess, 179.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 177.5ms
# Speed: 1.8ms preprocess, 177.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 180.1ms
# Speed: 1.9ms preprocess, 180.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 176.4ms
# Speed: 1.8ms preprocess, 176.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 180.0ms
# Speed: 1.9ms preprocess, 180.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
# 0: 480x640 1 person, 176.3ms
# Speed: 1.9ms preprocess, 176.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 200.9ms
# Speed: 21.1ms preprocess, 200.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 177.8ms
# Speed: 1.9ms preprocess, 177.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 178.3ms
# Speed: 2.0ms preprocess, 178.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 176.0ms
# Speed: 1.8ms preprocess, 176.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 177.9ms
# Speed: 1.9ms preprocess, 177.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 182.4ms
# Speed: 1.9ms preprocess, 182.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 178.8ms
# Speed: 1.8ms preprocess, 178.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 178.3ms
# Speed: 1.8ms preprocess, 178.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 177.5ms
# Speed: 2.0ms preprocess, 177.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 178.3ms
# Speed: 1.8ms preprocess, 178.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 1 cell phone, 177.6ms
# Speed: 1.8ms preprocess, 177.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# 0: 480x640 1 person, 177.2ms
# Speed: 1.9ms preprocess, 177.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 177.5ms
# Speed: 1.8ms preprocess, 177.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 177.6ms
# Speed: 2.0ms preprocess, 177.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
# 0: 480x640 1 person, 181.7ms
# Speed: 2.2ms preprocess, 181.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
# 0: 480x640 1 person, 177.4ms
# Speed: 2.0ms preprocess, 177.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
# 0: 480x640 1 person, 233.1ms
# Speed: 1.9ms preprocess, 233.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.77
# Class name --> person
# 0: 480x640 1 person, 177.3ms
# Speed: 1.9ms preprocess, 177.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 1 remote, 176.8ms
# Speed: 2.0ms preprocess, 176.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> remote
# 0: 480x640 1 person, 1 remote, 180.4ms
# Speed: 1.9ms preprocess, 180.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.55
# Class name --> remote
# 0: 480x640 2 persons, 1 remote, 177.6ms
# Speed: 2.0ms preprocess, 177.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.77
# Class name --> remote
# Confidence ---> 0.27
# Class name --> person
# 0: 480x640 1 person, 1 remote, 178.3ms
# Speed: 1.9ms preprocess, 178.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> remote
# Confidence ---> 0.8
# Class name --> person
# 0: 480x640 1 person, 1 remote, 181.5ms
# Speed: 2.0ms preprocess, 181.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> remote
# Confidence ---> 0.77
# Class name --> person
# 0: 480x640 1 person, 1 remote, 183.3ms
# Speed: 2.1ms preprocess, 183.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.79
# Class name --> remote
# 0: 480x640 2 persons, 1 remote, 183.4ms
# Speed: 2.1ms preprocess, 183.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> remote
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# 0: 480x640 1 person, 181.9ms
# Speed: 2.1ms preprocess, 181.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
# 0: 480x640 1 person, 187.5ms
# Speed: 2.2ms preprocess, 187.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 183.4ms
# Speed: 2.3ms preprocess, 183.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 186.5ms
# Speed: 2.3ms preprocess, 186.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 188.7ms
# Speed: 2.3ms preprocess, 188.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 187.5ms
# Speed: 2.0ms preprocess, 187.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 201.6ms
# Speed: 16.6ms preprocess, 201.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 185.1ms
# Speed: 2.2ms preprocess, 185.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
# 0: 480x640 1 person, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
# 0: 480x640 1 person, 186.5ms
# Speed: 2.2ms preprocess, 186.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
# 0: 480x640 2 persons, 189.8ms
# Speed: 2.0ms preprocess, 189.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# 0: 480x640 1 person, 185.4ms
# Speed: 2.4ms preprocess, 185.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.81
# Class name --> person
# 0: 480x640 1 person, 183.8ms
# Speed: 2.5ms preprocess, 183.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 194.6ms
# Speed: 2.3ms preprocess, 194.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
# 0: 480x640 1 person, 200.9ms
# Speed: 2.1ms preprocess, 200.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 198.9ms
# Speed: 2.5ms preprocess, 198.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 183.1ms
# Speed: 2.1ms preprocess, 183.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 187.1ms
# Speed: 1.9ms preprocess, 187.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 186.5ms
# Speed: 1.9ms preprocess, 186.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
